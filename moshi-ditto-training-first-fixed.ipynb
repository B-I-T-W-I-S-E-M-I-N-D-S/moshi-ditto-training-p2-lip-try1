# %%
# !git clone https://github.com/B-I-T-W-I-S-E-M-I-N-D-S/moshi-ditto-training-p2.git

# %%
# %cd moshi-ditto-training-p2

# %%
# !pip install huggingface_hub hf_transfer onnx rich transformers

# %%
# !pip uninstall -y torch torchaudio
# !pip install torch==2.2.2 torchaudio==2.2.2 --index-url https://download.pytorch.org/whl/cu121

# %%
# !bash ditto-train/scripts/setup_environment.sh

# %%
from huggingface_hub import snapshot_download
import os

repo_id = "Darknsu/HDTF_audio_video"
download_dir = "/workspace/"

# Create directory if it doesn't exist
os.makedirs(download_dir, exist_ok=True)

print("📥 Downloading HDTF dataset...")

snapshot_download(
    repo_id=repo_id,
    repo_type="dataset",
    local_dir=download_dir,
    local_dir_use_symlinks=False,
)

print("✅ File downloaded to:", download_dir)

# %%
# !tar -xzvf /workspace/HDTF.tar.gz -C /workspace/

# %%
from huggingface_hub import snapshot_download
import os

repo_id = "digital-avatar/ditto-talkinghead"
download_dir = "./ditto-train/checkpoints"

# Create directory if it doesn't exist
os.makedirs(download_dir, exist_ok=True)

print("📥 Downloading full repository...")

snapshot_download(
    repo_id=repo_id,
    repo_type="model",   # important
    local_dir=download_dir,
    local_dir_use_symlinks=False,  # ensures real files, not symlinks
)

print("✅ Repo downloaded to:", download_dir)

# %%
# !apt update -qq
# !apt-get install -y ffmpeg libcudnn8 libcudnn8-dev 2>&1 | tail -5
# !apt-get install -y libgles2 libgl1-mesa-glx libegl1-mesa

# %%
# !python /workspace/moshi-ditto-training-p2/ditto-train/example/get_data_info_json_for_trainset_example.py

# %%
# Download Wav2Lip SyncNet checkpoint
# !mkdir -p /workspace/moshi-ditto-training-p2/ditto-train/checkpoints/
# !wget -nc -O /workspace/moshi-ditto-training-p2/ditto-train/checkpoints/lipsync_expert.pth "https://iiitaphyd-my.sharepoint.com/personal/radrabha_m_research_iiit_ac_in/_layouts/15/download.aspx?share=EQGlZA_1-OWBg1qwONyKVdjBBQz4rIq-aQ1C7L2xQdYmGw"

# %%
# !USE_LIP_SYNC=1 HDTF_ROOT=/workspace/HDTF NUM_GPUS=1 bash ditto-train/scripts/prepare_and_train.sh
